# %%
import numpy as np
import pandas as pd
import os
import math
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Users/krzysztofwasniewski/opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
os.chdir('/Users/krzysztofwasniewski/Desktop/grant innowacyjność/Geografia energetyki rozproszonej SGH OPUS Jesień 2023/PSE 2017')

# %%
os.listdir()
# Out:
# ['PL_BPKD_20170701_20170731_20170801011323.csv',
#  'PL_BPKD_20171001_20171031_20171101003347.csv',
#  'BPKD 2017 korelacje.xlsx',
#  'PL_BPKD_20171201_20171231_20171231231633.csv',
#  'PL_BPKD_20170301_20170331_20170401012410.csv',
#  'PL_BPKD_20170401_20170430_20170501010812.csv',
#  'PL_BPKD_20170501_20170531_20170601012506.csv',
#  'PL_BPKD_20170101_20170131_20170131235630.csv',
#  'PL_BPKD_20171101_20171130_20171201002710.csv',
#  'PL_BPKD_20170901_20170930_20171001011951.csv',
#  'BPKD_2017_Opis godzinami.xlsx',
#  'BPKD_2017_Opis.xlsx',
#  'PL_BPKD_20170201_20170228_20170301003135.csv',
#  'BPKD_2017_Opis miesiącami.xlsx',
#  'PL_BPKD_20170601_20170630_20170701012502.csv',
#  'PL_BPKD_20170801_20170831_20170901012258.csv']

# %%
BPKD_07_2017=pd.DataFrame(pd.read_csv('PL_BPKD_20170701_20170731_20170801011323.csv',sep=';',header='infer'))
BPKD_07_2017.insert(0,"Month",201707)

BPKD_10_2017=pd.DataFrame(pd.read_csv('PL_BPKD_20171001_20171031_20171101003347.csv',sep=';',header='infer'))
BPKD_10_2017.insert(0,"Month",201710)

BPKD_12_2017=pd.DataFrame(pd.read_csv('PL_BPKD_20171201_20171231_20171231231633.csv',sep=';',header='infer'))
BPKD_12_2017.insert(0,"Month",201712)

BPKD_03_2017=pd.DataFrame(pd.read_csv('PL_BPKD_20170301_20170331_20170401012410.csv',sep=';',header='infer'))
BPKD_03_2017.insert(0,"Month",201703)

BPKD_04_2017=pd.DataFrame(pd.read_csv('PL_BPKD_20170401_20170430_20170501010812.csv',sep=';',header='infer'))
BPKD_04_2017.insert(0,"Month",201704)

BPKD_05_2017=pd.DataFrame(pd.read_csv('PL_BPKD_20170501_20170531_20170601012506.csv',sep=';',header='infer'))
BPKD_05_2017.insert(0,"Month",201705)

BPKD_01_2017=pd.DataFrame(pd.read_csv('PL_BPKD_20170101_20170131_20170131235630.csv',sep=';',header='infer'))
BPKD_01_2017.insert(0,"Month",201701)

BPKD_11_2017=pd.DataFrame(pd.read_csv('PL_BPKD_20171101_20171130_20171201002710.csv',sep=';',header='infer'))
BPKD_11_2017.insert(0,"Month",201711)

BPKD_09_2017=pd.DataFrame(pd.read_csv('PL_BPKD_20170901_20170930_20171001011951.csv',sep=';',header='infer'))
BPKD_09_2017.insert(0,"Month",201709)

BPKD_02_2017=pd.DataFrame(pd.read_csv('PL_BPKD_20170201_20170228_20170301003135.csv',sep=';',header='infer'))
BPKD_02_2017.insert(0,"Month",201702)

BPKD_06_2017=pd.DataFrame(pd.read_csv('PL_BPKD_20170601_20170630_20170701012502.csv',sep=';',header='infer'))
BPKD_06_2017.insert(0,"Month",201706)

BPKD_08_2017=pd.DataFrame(pd.read_csv('PL_BPKD_20170801_20170831_20170901012258.csv',sep=';',header='infer'))
BPKD_08_2017.insert(0,"Month",201708)

# %%
BPKD_2017=pd.concat([BPKD_01_2017,BPKD_02_2017,BPKD_03_2017,BPKD_04_2017,BPKD_05_2017,BPKD_06_2017,BPKD_07_2017,
                    BPKD_08_2017,BPKD_09_2017,BPKD_10_2017,BPKD_11_2017,BPKD_12_2017])
BPKD_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8760 entries, 0 to 743
# Data columns (total 17 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Month                                                  8760 non-null   int64
#  1   Data                                                   8760 non-null   object
#  2   Godzina                                                8760 non-null   object
#  3   Krajowe zapotrzebowanie na moc                         8760 non-null   int64
#  4   Suma zdolno�ci wytw�rczych JWCD                        8760 non-null   int64
#  5   Suma zdolno�ci wytw�rczych IRZ                         8760 non-null   int64
#  6   Suma zdolno�ci wytw�rczych nJWCD                       8760 non-null   int64
#  7   Generacja JWCD                                         8760 non-null   int64
# ...

# %%
BPKD_2017.groupby('Month').describe().to_excel('BPKD_2017_Opis miesiącami.xlsx')
BPKD_2017.groupby('Godzina').describe().to_excel('BPKD_2017_Opis godzinami.xlsx')
BPKD_2017.groupby('Month').sum().to_excel('BPKD_2017_Suma miesiącami.xlsx')

# %%
BPKD_2017_correl=pd.DataFrame(BPKD_2017.corr(method='pearson'))
BPKD_2017_correl.to_excel('BPKD 2017 korelacje.xlsx')

# %%
BPKD_2017.describe()
# Out:
#                Month  Krajowe zapotrzebowanie na moc  \
# count    8760.000000                     8760.000000
# mean   201706.526826                    19235.289384
# std         3.448042                     3138.917985
# min    201701.000000                    11795.000000
# 25%    201704.000000                    16571.500000
# 50%    201707.000000                    19417.500000
# 75%    201710.000000                    21706.000000
# max    201712.000000                    25956.000000
#
#        Suma zdolno�ci wytw�rczych JWCD  Suma zdolno�ci wytw�rczych IRZ  \
# count                      8760.000000                     8760.000000
# mean                      19817.005936                      772.473744
# std                        1106.537233                      113.516967
# min                       16736.000000                      248.000000
# 25%                       19093.000000                      707.000000
# ...
